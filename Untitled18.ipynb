# %%
def selectionsort(arr,n):
  for i in range(n):
      Min=i
      for j in range(i+1,n):
          if(arr[j]< arr[Min]):
              Min=j
      temp=arr[i]
      arr[i]=arr[Min]
      arr[Min]=temp
  print(arr)
print("\n program for selection sort")
print("\n how many elements are there in Array?")
n=int(input())
array=[]
i=0
for i in range(n):
    print("\n enter elementin array")
    item=int(input())
    array.append(item)
print("orignal array is")
print(array)
print("\n sorted Array is")
selectionsort(array,n)
# Out:
#  program for selection sort
#
#  how many elements are there in Array?
# 3
#
#  enter elementin array
# 2
#
#  enter elementin array
# 77
#
#  enter elementin array
# 33
# orignal array is
# [2, 77, 33]
#
#  sorted Array is
# [2, 33, 77]
